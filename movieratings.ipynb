# %% [markdown]
# <a href="https://colab.research.google.com/github/munyuawilson/KaruWebScraping/blob/main/movieratings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn as sk 
import pandas as pd 
import matplotlib as plt
from google.colab import files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_one=pd.read_csv("/content/drive/MyDrive/movies.csv")
data_two=pd.read_csv("/content/drive/MyDrive/ratings.csv")
New_data={
"MovieID":data_two.movieId,
"Ratings":data_two.rating
}

# %%
new_dataframe=pd.DataFrame(New_data)
bargaraph=new_dataframe.head(100).plot.line(x="MovieID",y="Ratings")
